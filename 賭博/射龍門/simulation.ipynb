# %% [markdown]
# # 射龍門配對抽牌模擬
# `utils.launch_interactive_simulation` 提供互動按鈕介面；使用前請先執行下面的 reload cell，確保 notebook 讀到的是最新版模組。
# - `DECK_COUNT` 控制副數大小，改完後重新執行 `launch_interactive_simulation` 這個 cell 便會以新樣本空間啟動。
# - `SEED` 可固定洗牌結果以便重現。
# - UI 會顯示底牌/棄牌數量、各段（1~3 / 4~6 / 7~9 / 10~13）剩餘張數，以及可按鈕式抽牌。

# %%
import importlib, utils
importlib.reload(utils)
from utils import launch_interactive_simulation

print("launch exists:", "launch_interactive_simulation" in dir(utils))
print("module path:", utils.__file__)
# Out:
# launch exists: True
# module path: d:\Github\Personal-Project\賭博\射龍門\utils.py

# %%
DECK_COUNT = 2
SEED = 20260414

launch_interactive_simulation(deck_count=DECK_COUNT, seed=SEED)

# %% [markdown]
# ### 使用提示
# 1. 再按一下「抽兩張」就會從底牌抽出一對，畫面會同步顯示底牌、棄牌、以及各段剩餘。若出現提示底牌不足，先按「洗回棄牌」或「從頭再來」。
# 2. 想檢視抽牌紀錄時再打開「顯示抽牌紀錄」切換按鈕，預設會保持收起以維持版面簡潔。
# 3. 若想改副數或 seed，調整 `DECK_COUNT`/`SEED` 後重新執行 `launch_interactive_simulation` cell 就會用新的樣本空間啟動。
